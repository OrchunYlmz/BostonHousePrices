# %% [markdown]
# <a href="https://colab.research.google.com/github/OrchunYlmz/BostonHousePrices/blob/main/BostonHousePricing(MyFirstML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the CSV dataset into a DataFrame
df = pd.read_csv('/content/housing.csv')

# %%
df.head(10) #show the first 10 rows
# Out:
#    0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...
# 5   0.08829  12.50   7.870  0  0.5240  6.0120  66...
# 6   0.14455  12.50   7.870  0  0.5240  6.1720  96...
# 7   0.21124  12.50   7.870  0  0.5240  5.6310 100...
# 8   0.17004  12.50   7.870  0  0.5240  6.0040  85...
# 9   0.22489  12.50   7.870  0  0.5240  6.3770  94...

# %%
df.tail(10) #Show the last 10 rows
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 495   0.28960   0.00   9.690  0  0.5850  5.3900  72...
# 496   0.26838   0.00   9.690  0  0.5850  5.7940  70...
# 497   0.23912   0.00   9.690  0  0.5850  6.0190  65...
# 498   0.17783   0.00   9.690  0  0.5850  5.5690  73...
# 499   0.22438   0.00   9.690  0  0.5850  6.0270  79...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...

# %%
#Creating columns
column_names=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PRTATIO","B","LSTAT","MEDV"]
#Load the CSV dataset into a DataFrame
df = pd.read_csv('/content/housing.csv',header=None,delimiter= r"\s+",names=column_names)

# %%
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PRTATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
df['INDUS'].plot(kind='hist', bins=20, title='INDUS')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['ZN'].plot(kind='hist', bins=20, title='ZN')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['CRIM'].plot(kind='hist', bins=20, title='CRIM')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.tail(10)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 496  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391.0
# 497  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391.0
# 498  0.23912  0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391.0
# 499  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391.0
# 500  0.22438  0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391.0
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PRTATIO       B  LSTAT  MEDV
# 496     19.2  396.90  21.14  19.7
# 497     19.2  396.90  14.10  18.3
# 498     19.2  396.90  12.92  21.2
# 499     19.2  395.77  15.10  17.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PRTATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# **We have 506 entries for each column, 13 columns, CHAS and RAD is int, rest is float.Also all of the entries are non-null.**

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PRTATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# **Here we can see mean, std, min, max, 25%, 50%, 75% and count.**

# %%
missing_values_percentage = (df.isnull().sum() / len(df)).reset_index(name='Percentage')

# %%
print(missing_values_percentage[missing_values_percentage['Percentage'] > 0])
# Out:
# Empty DataFrame
# Columns: [index, Percentage]
# Index: []

# %% [markdown]
# **This means that there are not any missing values.**

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PRTATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
corr_matrix = df.corr() #Calculate the correlation matrix.
corr_above_05=corr_matrix.where(corr_matrix>0.5) #Filter for highly correlated features (correlation coefficient > 0.5)

# Create a heatmap of the filtered correlation matrix
sns.heatmap(corr_above_05, annot=True)
plt.title('Heatmap of Highly Correlated Features (Correlation > 0.5)')
plt.show()

# %% [markdown]
# **In this heatmap, we can see the columns with high correlation.**

# %%
corr_matrix = df.corr() #Calculate the correlation matrix.
corr_below_minus_05=corr_matrix.where(corr_matrix<-0.5) #Filter for less correlated features (correlation coefficient < -0.5)

# Create a heatmap of the filtered correlation matrix
sns.heatmap(corr_below_minus_05, annot=True)
plt.title('Heatmap of Less Correlated Features (Correlation < -0.5)')
plt.show()

# %% [markdown]
# **In this heatmap, we can see the columns with low correlation.**

# %%
correlation_threshold = 0.5

# Filter correlation matrix for highly positive correlations
corr_above_pos_threshold = corr_matrix.where(corr_matrix > correlation_threshold)

# Filter correlation matrix for highly negative correlations (absolute value)
corr_below_neg_threshold = corr_matrix.where(corr_matrix < -correlation_threshold).abs()

# Create heatmaps for positive and negative correlations
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Heatmap for positive correlations
sns.heatmap(corr_above_pos_threshold, annot=True, ax=axs[0])
axs[0].set_title('Heatmap of Highly Correlated Features (Correlation > 0.5)')

# Heatmap for negative correlations
sns.heatmap(corr_below_neg_threshold, annot=True, ax=axs[1])
axs[1].set_title('Heatmap of Less Correlated Features (Correlation < -0.5)')

plt.tight_layout()
plt.show()

# %% [markdown]
# **As we can see, now we can compare both heatmaps closely.**
#
#
#
# *   CRIM is highly correlated with RAD.
# *   ZN is correlated with DIS and less correlated with INDUS, NOX, AGE.
# *   INDUS is highly correlated with NOX and TAX, less correlated with DIS.
# *   NOX is less correlated with DIS, this may mean that as DIS increases, NOX decreases.
# *   RM is highly correlated with MEDV, less correlated with LSTAT.
# *   AGE highly correlated with NOX, this may mean that when NOX increases, aging process also increases.
# *   TAX is highly correlated with RAD and INDUS.

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))

sns.scatterplot(x = 'AGE', y = 'DIS', data = df)

plt.show()

# %% [markdown]
# **It seems like the houses get closer to the Boston job centers as the number of old houses in the town increases.**

# %%
# Scatterplot to visulaize the relationship between RAD and TAX
plt.figure(figsize = (6, 6))

sns.scatterplot(x = 'RAD', y = 'TAX', data = df)

plt.show()

# %% [markdown]
# **The relationship between RAD and TAX is strongly noticeable, but there isn't a distinct pattern between these two variables. The significant correlation may be due to uncommon data points or outliers.**:

# %%
# Remove the data corresponding to high tax rate
df1 = df[df['TAX'] < 600]

# Import the required function
from scipy.stats import pearsonr

# Calculate the correlation
print('The correlation between TAX and RAD is', pearsonr(df1['TAX'], df1['RAD'])[0])
# Out:
# The correlation between TAX and RAD is 0.24975731331429196

# %% [markdown]
# **Therefore, the strong correlation between TAX and RAD stems from the outliers. It's possible that certain properties have higher tax rates for reasons unrelated to RAD.**

# %%
# Scatterplot to visulaize the relationship between RM and MEDV
plt.figure(figsize = (6, 6))

sns.scatterplot(x = 'RM', y = 'MEDV', data = df)

plt.show()

# %% [markdown]
# **Seems like prive of the house increases as the value of the RM/Room increases**

# %% [markdown]
# # **Split the dataset**

# %%
from sklearn.model_selection import train_test_split

# Separate independent variables (X) and target variable (y)
X = df.drop("MEDV", axis=1) # MEDV is our target variable
y = df["MEDV"]

# Split the dataset into training and testing sets (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Check the size of training and testing sets
print("Training data size:", X_train.shape)
print("Test data size:", X_test.shape)
# Out:
# Training data size: (354, 13)
# Test data size: (152, 13)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Define the pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('regression', LinearRegression())
])

# Define hyperparameters for Grid Search
param_grid = {
    'regression__fit_intercept': [True, False],
    'scaler__with_mean': [True, False],
    'scaler__with_std': [True, False]
}

# Grid Search
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Evaluate model
print("Grid Search - Best Score:", -grid_search.best_score_)
print("Grid Search - Best Params:", grid_search.best_params_)
# Out:
# Grid Search - Best Score: 25.977777430926267
# Grid Search - Best Params: {'regression__fit_intercept': True, 'scaler__with_mean': True, 'scaler__with_std': True}

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Function to calculate VIF
def calculate_vif(X):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
    return vif_data

# Check VIF for all features
vif_df = calculate_vif(X)
print(vif_df)

# Drop features with VIF greater than 5 iteratively until all features have VIF less than 5
while vif_df['VIF'].max() > 5:
    max_vif_feature = vif_df.loc[vif_df['VIF'].idxmax()]['Feature']
    X.drop(max_vif_feature, axis=1, inplace=True)
    print(f"Dropped feature with high VIF: {max_vif_feature}")
    vif_df = calculate_vif(X)
    print(vif_df)
# Out:
#     Feature        VIF
# 0      CRIM   2.100373
# 1        ZN   2.844013
# 2     INDUS  14.485758
# 3      CHAS   1.152952
# 4       NOX  73.894947
# 5        RM  77.948283
# 6       AGE  21.386850
# 7       DIS  14.699652
# 8       RAD  15.167725
# 9       TAX  61.227274
# 10  PRTATIO  85.029547
# 11        B  20.104943
# 12    LSTAT  11.102025
# Dropped feature with high VIF: PRTATIO
#    Feature        VIF
# 0     CRIM   2.099345
# 1       ZN   2.451624
# 2    INDUS  14.275283
# 3     CHAS   1.142167
# 4      NOX  73.894171
# 5       RM  60.598846
# 6      AGE  21.361234
# 7      DIS  12.221605
# 8      RAD  15.159162
# 9      TAX  59.301541
# 10       B  18.614751
# 11   LSTAT  10.138324
# Dropped feature with high VIF: NOX
#    Feature        VIF
# 0     CRIM   2.097537
# 1       ZN   2.449661
# 2    INDUS  13.150904
# 3     CHAS   1.138277
# 4       RM  41.406746
# 5      AGE  19.889623
# 6      DIS  12.032952
# 7      RAD  15.155012
# 8      TAX  57.720347
# ...

# %%
# Separate the dependent variable and indepedent variables
df['MEDV_log'] = np.log(df['MEDV'])
Y = df['MEDV_log']

X = df.drop(columns = {'MEDV', 'MEDV_log'})

# Add the intercept term
X = sm.add_constant(X)

# %%
# splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    # Calculating VIF for each feature
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]
    return vif

# %%
# Create the model after dropping TAX
X_train = X_train.drop(columns = 'TAX')

# Check for VIF
print(checking_vif(X_train))
# Out:
#     feature         VIF
# 0     const  581.372515
# 1      CRIM    1.992236
# 2        ZN    2.483521
# 3     INDUS    3.277778
# 4      CHAS    1.052841
# 5       NOX    4.397232
# 6        RM    1.876243
# 7       AGE    3.154114
# 8       DIS    4.339453
# 9       RAD    2.978247
# 10  PRTATIO    1.914523
# 11        B    1.384927
# 12    LSTAT    2.924524

# %%
# Create the model after dropping columns 'MEDV', 'MEDV_log', 'TAX', 'ZN', 'AGE', 'INDUS' from df DataFrame
Y = df['MEDV_log']

X = df.drop(['ZN','AGE','INDUS'], axis=1)

X = sm.add_constant(X)

# Splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30 , random_state = 1)

# Create the model
model2 = sm.OLS(y_train,X_train).fit()

# Get the model summary
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               MEDV_log   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.368e+30
# Date:                Mon, 06 May 2024   Prob (F-statistic):               0.00
# Time:                        19:53:20   Log-Likelihood:                 11507.
# No. Observations:                 354   AIC:                        -2.299e+04
# Df Residuals:                     341   BIC:                        -2.294e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.661e-16   4.27e-15     -0.156      0.876   -9.06e-15    7.73e-15
# ...

# %% [markdown]
# **It's worth mentioning that the regression coefficients associated with ZN, AGE, and INDUS are not statistically significant. Put differently, the regression coefficients for these three variables aren't markedly distinct from 0 in the overall population. Consequently, we'll discard these three features.**

# %%
residuals = model2.resid

np.mean(residuals)
# Out:
# 1.674743206637948e-16

# %%
from statsmodels.stats.diagnostic import het_white

from statsmodels.compat import lzip

import statsmodels.stats.api as sms

name = ["F statistic", "p-value"]

test = sms.het_goldfeldquandt(y_train, X_train)

lzip(name, test)
# Out:
# [('F statistic', 0.004761694209732108), ('p-value', 0.9999999999999999)]

# %%
# Predicted values
fitted = model2.fittedvalues

# sns.set_style("whitegrid")
sns.residplot(x = fitted, y = residuals, color = "lightblue", lowess = True)

plt.xlabel("Fitted Values")

plt.ylabel("Residual")

plt.title("Residual PLOT")

plt.show()

# %%
# Plot histogram of residuals

sns.histplot(residuals, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Plot q-q plot of residuals
import pylab

import scipy.stats as stats

stats.probplot(residuals, dist = "norm", plot = pylab)

plt.show()

# %% [markdown]
# # Checking the performance of the model.

# %%
# RMSE
def rmse(predictions, targets):
    return np.sqrt(((targets - predictions) ** 2).mean())


# MAPE
def mape(predictions, targets):
    return np.mean(np.abs((targets - predictions)) / targets) * 100


# MAE
def mae(predictions, targets):
    return np.mean(np.abs((targets - predictions)))

## R2
from sklearn.metrics import r2_score


# Model Performance on test and train data
def model_pref(olsmodel, x_train, x_test):

    # In-sample Prediction
    y_pred_train = olsmodel.predict(x_train)
    y_observed_train = y_train

    # Prediction on test data
    y_pred_test = olsmodel.predict(x_test)
    y_observed_test = y_test

    print(
        pd.DataFrame(
            {
                "Data": ["Train", "Test"],
                "RMSE": [
                    rmse(y_pred_train, y_observed_train),
                    rmse(y_pred_test, y_observed_test),
                ],
                "MAE": [
                    mae(y_pred_train, y_observed_train),
                    mae(y_pred_test, y_observed_test),
                ],
                "MAPE": [
                    mape(y_pred_train, y_observed_train),
                    mape(y_pred_test, y_observed_test),
                ],
                "r2": [
                    r2_score(y_pred_train, y_observed_train),
                    r2_score(y_pred_test, y_observed_test),
                ],
            }
        )
    )


# Checking model performance
model_pref(model2, X_train, X_test)
# Out:
#     Data          RMSE           MAE          MAPE   r2
# 0  Train  1.846667e-15  1.593829e-15  5.391714e-14  1.0
# 1   Test  1.689986e-15  1.453516e-15  4.964099e-14  1.0

# %% [markdown]
# **:The training and testing results are quite similar, which suggests our model isn't overfit and performs well across different datasets. Since the scores are very close, it's unlikely we can significantly improve the model's performance.**

# %%
# Import the required function

from sklearn.model_selection import cross_val_score

# Build the regression model and cross-validate
linearregression = LinearRegression()

cv_Score11 = cross_val_score(linearregression, X_train, y_train, cv = 10)
cv_Score12 = cross_val_score(linearregression, X_train, y_train, cv = 10,
                             scoring = 'neg_mean_squared_error')


print("RSquared: %0.3f (+/- %0.3f)" % (cv_Score11.mean(), cv_Score11.std() * 2))
print("Mean Squared Error: %0.3f (+/- %0.3f)" % (-1*cv_Score12.mean(), cv_Score12.std() * 2))
# Out:
# RSquared: 1.000 (+/- 0.000)
# Mean Squared Error: 0.000 (+/- 0.000)

# %% [markdown]
# **The model is already at peak performance and did not improve.**

# %%
coef = model2.params

pd.DataFrame({'Feature' : coef.index, 'Coefs' : coef.values})
# Out:
#      Feature         Coefs
# 0      const -6.661338e-16
# 1       CRIM -2.428613e-17
# 2       CHAS  2.772088e-15
# 3        NOX -7.771561e-16
# 4         RM -1.387779e-17
# 5        DIS -3.330669e-16
# 6        RAD  8.153200e-17
# 7        TAX  2.222614e-18
# 8    PRTATIO  1.973248e-16
# 9          B  6.076469e-19
# 10     LSTAT  6.505213e-18
# 11      MEDV  9.974660e-17
# 12  MEDV_log  1.000000e+00

# %%
# Let us write the equation of the fit

equation = "log (Price) = "

print(equation, end = '\t')

for i in range(len(coef)):
    print('(', coef[i], ') * ', coef.index[i], '+', end = ' ')
# Out:
# log (Price) = 	( -6.661338147750939e-16 ) *  const + ( -2.42861286636753e-17 ) *  CRIM + ( 2.7720881146109377e-15 ) *  CHAS + ( -7.771561172376096e-16 ) *  NOX + ( -1.3877787807814457e-17 ) *  RM + ( -3.3306690738754696e-16 ) *  DIS + ( 8.153200337090993e-17 ) *  RAD + ( 2.222614453595284e-18 ) *  TAX + ( 1.973247953923618e-16 ) *  PRTATIO + ( 6.076468779814541e-19 ) *  B + ( 6.5052130349130266e-18 ) *  LSTAT + ( 9.974659986866641e-17 ) *  MEDV + ( 0.9999999999999981 ) *  MEDV_log +
